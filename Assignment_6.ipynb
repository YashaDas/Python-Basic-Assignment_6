# %% [markdown]
# # Python Basic Assignment_6

# %% [markdown]
# ###  1. What are escape characters, and how do you use them?

# %% [markdown]
# ##### ANSWER:
#
# Escape Characters: Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code.
#
# Escape characters can be used in the following manner:

# %%
#For example:

a = "I am a student of "iNeuron""
# Out:
#   File "<ipython-input-1-0e1dced005fe>", line 1
#     a = "I am a student of "iNeuron""
#                                   ^
# SyntaxError: invalid syntax

# %%
#After using the escape character '\':

a = "I am a student of \"iNeuron\""
print(a)
# Out:
# I am a student of "iNeuron"

# %% [markdown]
# ### 2. What do the escape characters n and t stand for?

# %% [markdown]
# ##### ANSWER:
#
# - \n - is a newline.
#
# - \t - is a tab.

# %%
#For example:

b = "Hello\nWorld!"
print(b)
# Out:
# Hello
# World!

# %%
c = "Hello\tWorld!"
print(c)
# Out:
# Hello	World!

# %% [markdown]
# ### 3. What is the way to include backslash characters in a string?

# %% [markdown]
# ##### ANSWER:
#
# To include backslash characters in a string, use an escape character.An escape character is a backslash \ followed by the character you want to insert.

# %%
#For example:

d = "This will insert one \\ (backslash)."
print(d)
# Out:
# This will insert one \ (backslash).

# %% [markdown]
# ### 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [markdown]
# ##### ANSWER:
#
# The single quote character in the word Howl's not escaped a problem as double quotes are used to mark the beginning and end of the string.

# %%
e = "Howl's Moving Castle"
print(e)
# Out:
# Howl's Moving Castle

# %% [markdown]
# ### 5. How do you write a string of newlines if you don't want to use the n character?

# %% [markdown]
# ##### ANSWER:
#
# To a string of newlines if you don't want to use the n character, you can do so by using multiline strings.You can assign a multiline string to a variable by using three single or double quotes.

# %%
#For Example:

f = '''abcdefagijklmnopqrstqwerty,
fiogjhtriojrpjrpojeojnaalqw gsPEKOE,
F GNHHJIdsgdhrtjh o ekt wn pepyoyjjrto'''
print(f)
# Out:
# abcdefagijklmnopqrstqwerty,
# fiogjhtriojrpjrpojeojnaalqw gsPEKOE,
# F GNHHJIdsgdhrtjh o ekt wn pepyoyjjrto

# %%
g = """geiohe goi ewnworrn wnw ow,
in wio gerneinwqqswxkcwamgelrghkr or,
qifwe noigen eoihnth eo hnhoprh rpho"""
print(g)
# Out:
# geiohe goi ewnworrn wnw ow,
# in wio gerneinwqqswxkcwamgelrghkr or,
# qifwe noigen eoihnth eo hnhoprh rpho

# %% [markdown]
# ##### NOTE: I just pressed random key's for example.

# %% [markdown]
# ### 6. What are the values of the given expressions?
#
# 'Hello, world!'[1]
#
# 'Hello, world!'[0:5]
#
# 'Hello, world!'[:5]
#
# 'Hello, world!'[3:]

# %% [markdown]
# ##### ANSWER:

# %%
'Hello, world!'[1]
# Out:
# 'e'

# %%
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %% [markdown]
# ### 7. What are the values of the following expressions?
#
# 'Hello'.upper()
#
# 'Hello'.upper().isupper()
#
# 'Hello'.upper().lower()

# %% [markdown]
# ##### ANSWER:

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ### 8. What are the values of the following expressions?
#
# 'Remember, remember, the fifth of July.'.split()
#
# '-'.join('There can only one.'.split())

# %% [markdown]
# ##### ANSWER:

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ### 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# ##### ANSWER:
#
# The following are the string method:

# %% [markdown]
# ##### right-justifying : rjust()

# %%
# For example:

h = "Hello"
i = h.rjust(20)
print(h, "i am a student")
# Out:
# Hello i am a student

# %% [markdown]
# ##### left-justifying : ljust()

# %%
# For example:

j = "iNeuron"
k = j.ljust(20)
print("I am a student of",j)
# Out:
# I am a student of iNeuron

# %% [markdown]
# ##### centering a string - center()

# %%
l = "Center"
m = l.center(20)
print(m)
# Out:
#        Center

# %% [markdown]
# ### 10. What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# ##### ANSWER:
#
# The best way to remove whitespace characters from the start or end, is to use lstrip() and rstrip() respectively.

# %% [markdown]
# ##### lstrip()

# %%
# For example:

n = "        i like eating ice cream in summer"
n
# Out:
# '        i like eating ice cream in summer'

# %%
o = n.lstrip()
print(o)
# Out:
# i like eating ice cream in summer

# %% [markdown]
# ##### rstrip()

# %%
# For example:

p = "i like riding bicycle           "
p
# Out:
# 'i like riding bicycle           '

# %%
q = p.rstrip()
print(q)
# Out:
# i like riding bicycle
